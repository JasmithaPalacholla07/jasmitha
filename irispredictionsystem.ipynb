# %%
# %pip install numpy
# %pip install pandas
# %pip install matplotlib
# %pip install seaborn
# %pip install joblib
# %pip install scikit-learn
# Out:
# Requirement already satisfied: numpy in c:\Users\Jasmitha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (2.5.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in c:\Users\Jasmitha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (3.0.5)
# Requirement already satisfied: numpy>=2.3.3 in c:\Users\Jasmitha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas) (2.5.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Jasmitha\AppData\Roaming\Python\Python314\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\Jasmitha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas) (2026.3)
# Requirement already satisfied: six>=1.5 in C:\Users\Jasmitha\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in c:\Users\Jasmitha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (3.11.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\Jasmitha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\Jasmitha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in c:\Users\Jasmitha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\Jasmitha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (1.5.1)
# Requirement already satisfied: numpy>=1.25 in c:\Users\Jasmitha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (2.5.2)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Jasmitha\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (26.3)
# Requirement already satisfied: pillow>=9 in c:\Users\Jasmitha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\Jasmitha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\Jasmitha\AppData\Roaming\Python\Python314\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\Jasmitha\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: seaborn in c:\Users\Jasmitha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\Users\Jasmitha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from seaborn) (2.5.2)
# Requirement already satisfied: pandas>=1.2 in c:\Users\Jasmitha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from seaborn) (3.0.5)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\Users\Jasmitha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from seaborn) (3.11.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\Users\Jasmitha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\Users\Jasmitha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in c:\Users\Jasmitha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\Users\Jasmitha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in C:\Users\Jasmitha\AppData\Roaming\Python\Python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.3)
# Requirement already satisfied: pillow>=9 in c:\Users\Jasmitha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\Users\Jasmitha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\Jasmitha\AppData\Roaming\Python\Python314\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\Jasmitha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from pandas>=1.2->seaborn) (2026.3)
# Requirement already satisfied: six>=1.5 in C:\Users\Jasmitha\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: joblib in c:\Users\Jasmitha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (1.6.0)
# Requirement already satisfied: cloudpickle>=3.0 in c:\Users\Jasmitha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from joblib) (3.1.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in c:\Users\Jasmitha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (1.9.0)
# Requirement already satisfied: numpy>=1.24.1 in c:\Users\Jasmitha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-learn) (2.5.2)
# Requirement already satisfied: scipy>=1.10.0 in c:\Users\Jasmitha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-learn) (1.18.1)
# Requirement already satisfied: joblib>=1.4.0 in c:\Users\Jasmitha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-learn) (1.6.0)
# Requirement already satisfied: narwhals>=2.0.1 in c:\Users\Jasmitha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-learn) (2.25.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\Users\Jasmitha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: cloudpickle>=3.0 in c:\Users\Jasmitha\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from joblib>=1.4.0->scikit-learn) (3.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
iris = load_iris()

df = pd.DataFrame(
    iris.data,
    columns=iris.feature_names
)

df["species"] = iris.target

df["species"] = df["species"].map({
    0: "setosa",
    1: "versicolor",
    2: "virginica"
})

print("Iris dataset loaded successfully!")
print("Rows and columns:", df.shape)

display(df.head())
# Out:
# Iris dataset loaded successfully!
# Rows and columns: (150, 5)
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
print("Column names:")
print(df.columns.tolist())

print("\nDataset information:")
df.info()

print("\nMissing values:")
print(df.isnull().sum())

print("\nDuplicate rows:", df.duplicated().sum())
# Out:
# Column names:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)', 'species']
#
# Dataset information:
# <class 'pandas.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   species            150 non-null    str
# dtypes: float64(4), str(1)
# memory usage: 6.0 KB
#
# Missing values:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# species              0
# dtype: int64
#
# Duplicate rows: 1

# %%
display(df.describe(include="all").T)

print("\nSpecies distribution:")
display(df["species"].value_counts())
# Out:
#                    count unique     top freq      mean       std  min  25%  \
# sepal length (cm)  150.0    NaN     NaN  NaN  5.843333  0.828066  4.3  5.1
# sepal width (cm)   150.0    NaN     NaN  NaN  3.057333  0.435866  2.0  2.8
# petal length (cm)  150.0    NaN     NaN  NaN     3.758  1.765298  1.0  1.6
# petal width (cm)   150.0    NaN     NaN  NaN  1.199333  0.762238  0.1  0.3
# species              150      3  setosa   50       NaN       NaN  NaN  NaN
#
#                     50%  75%  max
# sepal length (cm)   5.8  6.4  7.9
# sepal width (cm)    3.0  3.3  4.4
# petal length (cm)  4.35  5.1  6.9
# petal width (cm)    1.3  1.8  2.5
# species             NaN  NaN  NaN
# Species distribution:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))

sns.countplot(
    data=df,
    x="species"
)

plt.title("Number of Flowers by Species")
plt.xlabel("Flower Species")
plt.ylabel("Count")

plt.show()

# %%
sns.pairplot(
    df,
    hue="species"
)

plt.show()

# %%
numeric_df = df.drop(columns=["species"])

plt.figure(figsize=(8,6))

sns.heatmap(
    numeric_df.corr(),
    annot=True,
    cmap="coolwarm"
)

plt.title("Feature Correlation")

plt.show()

# %%
features = [
    "sepal length (cm)",
    "sepal width (cm)",
    "petal length (cm)",
    "petal width (cm)"
]

target = "species"

X = df[features]
y = df[target]

print("Features:")
display(X.head())

print("\nTarget:")
display(y.head())
# Out:
# Features:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
# Target:
# 0    setosa
# 1    setosa
# 2    setosa
# 3    setosa
# 4    setosa
# Name: species, dtype: str

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Training rows:", len(X_train))
print("Testing rows:", len(X_test))
# Out:
# Training rows: 120
# Testing rows: 30

# %%
model = Pipeline([
    ("scaler", StandardScaler()),
    ("classifier", RandomForestClassifier(
        n_estimators=100,
        random_state=42
    ))
])

model.fit(X_train, y_train)

print("Model trained successfully!")
# Out:
# Model trained successfully!

# %%
y_pred = model.predict(X_test)

print("Predictions:")
print(y_pred)
# Out:
# Predictions:
# ['setosa' 'virginica' 'versicolor' 'versicolor' 'setosa' 'versicolor'
#  'setosa' 'setosa' 'virginica' 'versicolor' 'virginica' 'virginica'
#  'virginica' 'versicolor' 'setosa' 'setosa' 'setosa' 'versicolor'
#  'versicolor' 'versicolor' 'setosa' 'virginica' 'versicolor' 'versicolor'
#  'virginica' 'virginica' 'versicolor' 'setosa' 'virginica' 'setosa']

# %%
accuracy = accuracy_score(y_test, y_pred)

print("Model Accuracy:", accuracy)
print("Accuracy Percentage:", accuracy * 100, "%")
# Out:
# Model Accuracy: 0.9
# Accuracy Percentage: 90.0 %

# %%
print("Classification Report:")

print(
    classification_report(
        y_test,
        y_pred
    )
)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        10
#   versicolor       0.82      0.90      0.86        10
#    virginica       0.89      0.80      0.84        10
#
#     accuracy                           0.90        30
#    macro avg       0.90      0.90      0.90        30
# weighted avg       0.90      0.90      0.90        30

# %%
cm = confusion_matrix(
    y_test,
    y_pred
)

plt.figure(figsize=(7,5))

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    xticklabels=iris.target_names,
    yticklabels=iris.target_names
)

plt.title("Confusion Matrix")
plt.xlabel("Predicted Species")
plt.ylabel("Actual Species")

plt.show()

# %%
joblib.dump(
    model,
    "iris_flower_prediction_model.pkl"
)

print("Model saved successfully!")
# Out:
# Model saved successfully!

# %%
loaded_model = joblib.load(
    "iris_flower_prediction_model.pkl"
)

print("Saved model loaded successfully!")
# Out:
# Saved model loaded successfully!

# %%
new_flower = pd.DataFrame(
    [[5.1, 3.5, 1.4, 0.2]],
    columns=features
)

prediction = loaded_model.predict(new_flower)

print("Predicted Flower Species:", prediction[0])
# Out:
# Predicted Flower Species: setosa
